# %%
import glob
import os
import pandas as pd
coins_data = pd.read_csv("coins_data.csv")
csv_files = glob.glob(os.path.join("history/", '*.csv'))
dfs = []

for file in csv_files:
    # Extract the coin name from the file name
    coin_name = os.path.splitext(os.path.basename(file))[0].split('_')[0]
    
    df = pd.read_csv(file, sep=';')
    coin_id = coins_data.loc[coins_data['name'] == coin_name, 'rank'].values[0]
    df['id'] = coin_id
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)
combined_df.to_csv('all_historical_data.csv', index=False)

# %%
combined_df
# Out:
#                        timeOpen                 timeClose  \
# 0      2023-09-01T00:00:00.000Z  2023-09-01T23:59:59.999Z
# 1      2023-08-31T00:00:00.000Z  2023-08-31T23:59:59.999Z
# 2      2023-08-30T00:00:00.000Z  2023-08-30T23:59:59.999Z
# 3      2023-08-29T00:00:00.000Z  2023-08-29T23:59:59.999Z
# 4      2023-08-28T00:00:00.000Z  2023-08-28T23:59:59.999Z
# ...                         ...                       ...
# 67056  2022-09-07T00:00:00.000Z  2022-09-07T23:59:59.999Z
# 67057  2022-09-06T00:00:00.000Z  2022-09-06T23:59:59.999Z
# 67058  2022-09-05T00:00:00.000Z  2022-09-05T23:59:59.999Z
# 67059  2022-09-04T00:00:00.000Z  2022-09-04T23:59:59.999Z
# 67060  2022-09-03T00:00:00.000Z  2022-09-03T23:59:59.999Z
#
#                        timeHigh                   timeLow      open      high  \
# 0      2023-09-01T00:45:00.000Z  2023-09-01T18:05:00.000Z  1.429210  1.437624
# 1      2023-08-31T12:57:00.000Z  2023-08-31T21:10:00.000Z  1.474276  1.497287
# ...
